# %% [markdown]
# # `Gradient Boosting Tree`

# %%
import pandas as pd

# %% [markdown]
# ## Data analysis

# %% [markdown]
# ### Import the data

# %%
X = pd.read_csv('../data/X.csv')
X.head()
# Out:
#    date  gvkey       ROA       ROE  net_profit_margin  asset_turnover  \
# 0  1992  12994  0.037423  0.102068           0.036340        1.029794
# 1  1993  12994  0.046803  0.147029           0.046473        1.007108
# 2  1995  12994  0.047875  0.143644           0.049529        0.966617
# 3  1997  12994  0.030900  0.107777           0.033835        0.913251
# 4  1998  12994  0.035815  0.118648           0.035296        1.014703
#
#    inventory_turnover  debt_to_equity  debt_ratio   PE_ratio  market_to_book  \
# 0           16.255474        1.727451    0.633357  15.145384        1.545863
# 1           14.605198        2.141418    0.681672  14.007009        2.059430
# 2           12.073193        2.000380    0.666709  12.290482        1.765451
# 3            5.245672        2.487955    0.713299  15.038863        1.620843
# 4            7.190968        2.312778    0.698139  13.635444        1.617819
#
#    operating_cash_flow_to_debt  free_cash_flow_to_sales  book_value  ebitda  \
# ...

# %%
Y = pd.read_excel('../data/Project.xlsx')
Y.head()
# Out:
#   Project Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0   gvkey      fyear       conm      dlrsn      dldte  DateFiled    Chapter
# 1  001004       2010   AAR CORP        NaN        NaN        NaN        NaN
# 2  001004       2011   AAR CORP        NaN        NaN        NaN        NaN
# 3  001004       2012   AAR CORP        NaN        NaN        NaN        NaN
# 4  001004       2013   AAR CORP        NaN        NaN        NaN        NaN
#
#      Unnamed: 7    Unnamed: 8 Unnamed: 9
# 0  default_date  default_type          Y
# 1           NaN           NaN          0
# 2           NaN           NaN          0
# 3           NaN           NaN          0
# 4           NaN           NaN          0
